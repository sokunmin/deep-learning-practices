# %%
# %matplotlib inline

# %% [markdown]
# Data Loading and Processing Tutorial
# ====================================
# **Author**: [`Sasank Chilamkurthy`](https://chsasank.github.io)
#
# A lot of effort in solving any machine learning problem goes in to
# preparing the data. PyTorch provides many tools to make data loading
# easy and hopefully, to make your code more readable. In this tutorial,
# we will see how to load and preprocess/augment data from a non trivial
# dataset.
#
# To run this tutorial, please make sure the following packages are
# installed:
#
# -  ``scikit-image``: For image io and transforms
# -  ``pandas``: For easier csv parsing

# %%
from __future__ import print_function, division
import os
import torch
import pandas as pd
from skimage import io, transform
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

plt.ion()   # interactive mode

# %% [markdown]
# The dataset we are going to deal with is that of facial pose.
# This means that a face is annotated like this:
#
# .. figure:: /_static/img/landmarked_face2.png
#    :width: 400
#
# Over all, 68 different landmark points are annotated for each face.
#
# <div class="alert alert-info"><h4>Note</h4><p>
#
#     Download the dataset from https://download.pytorch.org/tutorial/faces.zip
#     so that the images are in a directory named 'data/faces/'.
#
#     This dataset was actually generated by applying excellent `dlib's pose
#     estimation https://blog.dlib.net/2014/08/real-time-face-pose-estimation.html
#     on a few images from imagenet tagged as 'face'.
# </p></div>
#
# Dataset comes with a csv file with annotations which looks like this:
#
# ::
#
#     image_name,part_0_x,part_0_y,part_1_x,part_1_y,part_2_x, ... ,part_67_x,part_67_y
#     0805personali01.jpg,27,83,27,98, ... 84,134
#     1084239450_e76e00b7e7.jpg,70,236,71,257, ... ,128,312
#
# Let's quickly read the CSV and get the annotations in an (N, 2) array where N
# is the number of landmarks.

# %%
from pathlib import Path
print('cwd = ', Path.cwd())
data_dir = Path.cwd().parent.parent / 'data' / 'faces'
print('data = ', data_dir)
# Out:
# cwd =  /home/nxtretail/workspace/practice/deep_learning_practices/pytorch_practice/get_started
# data =  /home/nxtretail/workspace/practice/deep_learning_practices/data/faces

# %%
csv_file = data_dir / 'face_landmarks.csv'
import os
assert os.path.exists(csv_file)
landmarks_frame = pd.read_csv(csv_file)

n = 65
img_name = landmarks_frame.iloc[n, 0]
landmarks = landmarks_frame.iloc[n, 1:].as_matrix()
print('Landmarks shape = ', landmarks.shape)
landmarks = landmarks.astype('float').reshape(-1, 2)

print('Image name: {}'.format(img_name))
print('Landmarks shape: {}'.format(landmarks.shape))
print('First 4 Landmarks: {}'.format(landmarks[:4]))
# Out:
# Landmarks shape =  (136,)
# Image name: person-7.jpg
# Landmarks shape: (68, 2)
# First 4 Landmarks: [[32. 65.]
#  [33. 76.]
#  [34. 86.]
#  [34. 97.]]

# %% [markdown]
# Let's write a simple helper function to show an image and its landmarks
# and use it to show a sample.

# %%
def show_landmarks(image, landmarks):
    """Show image with landmarks"""
    plt.imshow(image)
    plt.scatter(landmarks[:, 0], landmarks[:, 1], s=10, marker='.', c='r')
    plt.pause(0.001)  # pause a bit so that plots are updated

plt.figure()
show_landmarks(io.imread(data_dir / img_name), landmarks)
plt.show()

# %% [markdown]
# Dataset class
# -------------
#
# ``torch.utils.data.Dataset`` is an abstract class representing a
# dataset.
# Your custom dataset should inherit ``Dataset`` and override the following
# methods:
# <font color=blue>
# -  ``__len__`` so that ``len(dataset)`` returns the size of the dataset.
# -  ``__getitem__`` to support the indexing such that ``dataset[i]`` can
#    be used to get $i$-th sample
# </font>
# Let's create a dataset class for our face landmarks dataset. We will
# read the csv in ``__init__`` but leave the reading of images to
# ``__getitem__``. <br/><font color=red>This is memory efficient because all the images are not
# stored in the memory at once but read as required.</font>
#
# Sample of our dataset will be a dict ``{'image': image, 'landmarks': landmarks}``. <br/>Our dataset will take an
# optional argument ``transform`` so that any required processing can be
# applied on the sample. We will see the usefulness of ``transform`` in the
# next section.

# %%
class FaceLandmarksDataset(Dataset):
    """Face Landmarks dataset."""

    def __init__(self, csv_file, root_dir, transform=None):
        """
        Args:
            csv_file (string): Path to the csv file with annotations.
            root_dir (string): Directory with all the images.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.landmarks_frame = pd.read_csv(csv_file)
        self.root_dir = root_dir
        self.transform = transform

    def __len__(self):
        print('__len__ is called')
        return len(self.landmarks_frame)

    def __getitem__(self, idx):
        img_name = self.root_dir / self.landmarks_frame.iloc[idx, 0]
        #print('img_name = ', img_name)
        image = io.imread(img_name)
        landmarks = self.landmarks_frame.iloc[idx, 1:].as_matrix()
        landmarks = landmarks.astype('float').reshape(-1, 2)
        sample = {'image': image, 'landmarks': landmarks}

        if self.transform:
            sample = self.transform(sample)

        return sample

# %% [markdown]
# Let's instantiate this class and iterate through the data samples. We
# will print the sizes of first 4 samples and show their landmarks.

# %%
face_dataset = FaceLandmarksDataset(csv_file=data_dir / 'face_landmarks.csv',
                                    root_dir=data_dir)

fig = plt.figure()

for i in range(len(face_dataset)):
    sample = face_dataset[i]

    print(i, sample['image'].shape, sample['landmarks'].shape)

    ax = plt.subplot(1, 4, i + 1)
    plt.tight_layout()
    ax.set_title('Sample #{}'.format(i))
    ax.axis('off')
    show_landmarks(**sample) # unpack dict as arguments

    if i == 3:
        plt.show()
        break
# Out:
# img_name =  /home/nxtretail/workspace/practice/deep_learning_practices/data/faces/0805personali01.jpg
# 0 (324, 215, 3) (68, 2)
# img_name =  /home/nxtretail/workspace/practice/deep_learning_practices/data/faces/1084239450_e76e00b7e7.jpg
# 1 (500, 333, 3) (68, 2)
# img_name =  /home/nxtretail/workspace/practice/deep_learning_practices/data/faces/10comm-decarlo.jpg
# 2 (250, 258, 3) (68, 2)
# img_name =  /home/nxtretail/workspace/practice/deep_learning_practices/data/faces/110276240_bec305da91.jpg
# 3 (434, 290, 3) (68, 2)

# %% [markdown]
# Transforms
# ----------
#
# One issue we can see from the above is that the samples are not of the
# same size. Most neural networks expect the images of a fixed size.
# Therefore, we will need to write some prepocessing code.
# Let's create three transforms:
# <font color=blue>
# -  ``Rescale``: to scale the image
# -  ``RandomCrop``: to crop from image randomly. This is data
#    augmentation.
# -  ``ToTensor``: to convert the numpy images to torch images (we need to
#    swap axes).
# </font>
# We will write them as <font color=orange>callable classes</font> instead of simple functions so
# that parameters of the transform need not be passed everytime it's
# called.<br/><font color=red>For this, we just need to implement ``__call__`` method and
# if required, ``__init__`` method</font>. We can then use a transform like this:
#
# ::
#
#     tsfm = Transform(params)
#     transformed_sample = tsfm(sample)
#
# Observe below how these transforms had to be applied both on the image and
# landmarks.

# %%
class Rescale(object):
    """Rescale the image in a sample to a given size.

    Args:
        output_size (tuple or int): Desired output size. If tuple, output is
            matched to output_size. If int, smaller of image edges is matched
            to output_size keeping aspect ratio the same.
    """

    def __init__(self, output_size):
        assert isinstance(output_size, (int, tuple))
        self.output_size = output_size
        #print('[Rescale] output_size = ', output_size)

    def __call__(self, sample): # need to implement __call__ method
        image, landmarks = sample['image'], sample['landmarks']

        h, w = image.shape[:2]
        if isinstance(self.output_size, int):
            if h > w:
                new_h, new_w = self.output_size * h / w, self.output_size
            else:
                new_h, new_w = self.output_size, self.output_size * w / h
        else:
            new_h, new_w = self.output_size

        new_h, new_w = int(new_h), int(new_w)
        #print(f'[Rescale] new_size = {new_h} x {new_w} ')
        img = transform.resize(image, (new_h, new_w))

        # h and w are swapped for landmarks because for images,
        # x and y axes are axis 1 and 0 respectively
        landmarks = landmarks * [new_w / w, new_h / h]

        return {'image': img, 'landmarks': landmarks}


class RandomCrop(object):
    """Crop randomly the image in a sample.

    Args:
        output_size (tuple or int): Desired output size. If int, square crop
            is made.
    """

    def __init__(self, output_size):
        assert isinstance(output_size, (int, tuple))
        if isinstance(output_size, int):
            self.output_size = (output_size, output_size)
        else:
            assert len(output_size) == 2
            self.output_size = output_size

    def __call__(self, sample):
        image, landmarks = sample['image'], sample['landmarks']

        h, w = image.shape[:2]
        new_h, new_w = self.output_size
        # delta = size - new_size 
        # crop the image by a random position(x,y) sampled from delta.
        top = np.random.randint(0, h - new_h)
        left = np.random.randint(0, w - new_w)

        image = image[top: top + new_h,
                      left: left + new_w]

        landmarks = landmarks - [left, top]

        return {'image': image, 'landmarks': landmarks}


class ToTensor(object):
    """Convert ndarrays in sample to Tensors."""

    def __call__(self, sample):
        image, landmarks = sample['image'], sample['landmarks']

        # swap color axis because
        # numpy image: H x W x C
        # torch image: C X H X W
        image = image.transpose((2, 0, 1))
        return {'image': torch.from_numpy(image),
                'landmarks': torch.from_numpy(landmarks)}

# %% [markdown]
# ### Compose transforms
#
# Now, we apply the transforms on an sample.
#
# Let's say we want to rescale the shorter side of the image to 256 and
# then randomly crop a square of size 224 from it. i.e, we want to compose
# ``Rescale`` and ``RandomCrop`` transforms.
# ``torchvision.transforms.Compose`` is a simple callable class which allows us
# to do this.

# %%
scale = Rescale(256)
crop = RandomCrop(128)
composed = transforms.Compose([Rescale(256),
                               RandomCrop(224)])

# Apply each of the above transforms on sample.
fig = plt.figure()
sample = face_dataset[65]
for i, tsfrm in enumerate([scale, crop, composed]):
    transformed_sample = tsfrm(sample)

    ax = plt.subplot(1, 3, i + 1)
    plt.tight_layout()
    ax.set_title(type(tsfrm).__name__)
    show_landmarks(**transformed_sample)

plt.show()
# Out:
# [Rescale] output_size =  256
# [Rescale] output_size =  256
# img_name =  /home/nxtretail/workspace/practice/deep_learning_practices/data/faces/person-7.jpg
# [Rescale] new_size = 256 x 256
# [Rescale] new_size = 256 x 256

# %% [markdown]
# Iterating through the dataset
# -----------------------------
#
# Let's put this all together to create a dataset with composed
# transforms.
# To summarize, every time this dataset is sampled:
#
# -  An image is read from the file on the fly
# -  Transforms are applied on the read image
# -  Since one of the transforms is random, data is augmentated on
#    sampling
#
# We can iterate over the created dataset with a ``for i in range``
# loop as before.

# %%
transformed_dataset = FaceLandmarksDataset(csv_file=data_dir / 'face_landmarks.csv',
                                           root_dir=data_dir,
                                           transform=transforms.Compose([
                                               Rescale(256),
                                               RandomCrop(224),
                                               ToTensor()
                                           ]))
print('length = ', len(transformed_dataset))
for i in range(len(transformed_dataset)):
    sample = transformed_dataset[i]

    print(i, sample['image'].size(), sample['landmarks'].size())

    if i == 3:
        break
# Out:
# [Rescale] output_size =  256
# __len__ is called
# length =  69
# __len__ is called
# img_name =  /home/nxtretail/workspace/practice/deep_learning_practices/data/faces/0805personali01.jpg
# [Rescale] new_size = 385 x 256
# 0 torch.Size([3, 224, 224]) torch.Size([68, 2])
# img_name =  /home/nxtretail/workspace/practice/deep_learning_practices/data/faces/1084239450_e76e00b7e7.jpg
# [Rescale] new_size = 384 x 256
# 1 torch.Size([3, 224, 224]) torch.Size([68, 2])
# img_name =  /home/nxtretail/workspace/practice/deep_learning_practices/data/faces/10comm-decarlo.jpg
# [Rescale] new_size = 256 x 264
# 2 torch.Size([3, 224, 224]) torch.Size([68, 2])
# img_name =  /home/nxtretail/workspace/practice/deep_learning_practices/data/faces/110276240_bec305da91.jpg
# [Rescale] new_size = 383 x 256
# 3 torch.Size([3, 224, 224]) torch.Size([68, 2])

# %% [markdown]
# However, we are losing a lot of features by using a simple ``for`` loop to
# iterate over the data. In particular, we are missing out on:
# <font color=blue>
# -  Batching the data
# -  Shuffling the data
# -  Load the data in parallel using ``multiprocessing`` workers.
# </font><br/>
# `torch.utils.data.DataLoader` is an iterator which provides all these
# features. <br/>Parameters used below should be clear. <br/>One parameter of
# interest is `collate_fn`. <br/>You can specify how exactly the samples need
# to be batched using `collate_fn`. <br/>However, default collate should work
# fine for most use cases.

# %%
dataloader = DataLoader(transformed_dataset, batch_size=4, shuffle=True, num_workers=4)


# Helper function to show a batch
def show_landmarks_batch(sample_batched):
    """Show image with landmarks for a batch of samples."""
    images_batch, landmarks_batch = sample_batched['image'], sample_batched['landmarks']
    batch_size = len(images_batch)
    im_size = images_batch.size(2)

    grid = utils.make_grid(images_batch)
    # C x H x W → H x W x C
    plt.imshow(grid.numpy().transpose((1, 2, 0)))

    for i in range(batch_size):
        plt.scatter(landmarks_batch[i, :, 0].numpy() + i * im_size, 
                    landmarks_batch[i, :, 1].numpy(),
                    s=10, marker='.', c='r')

        plt.title('Batch from dataloader')

for i_batch, sample_batched in enumerate(dataloader):
    print(i_batch, 
          sample_batched['image'].size(),
          sample_batched['landmarks'].size())

    # observe 4th batch and stop.
    if i_batch == 3:
        plt.figure()
        show_landmarks_batch(sample_batched)
        plt.axis('off')
        plt.ioff()
        plt.show()
        break
# Out:
# img_name =  /home/nxtretail/workspace/practice/deep_learning_practices/data/faces/person.jpg
# img_name =  /home/nxtretail/workspace/practice/deep_learning_practices/data/faces/2327253037_66a61ea6fe.jpg
# img_name =  /home/nxtretail/workspace/practice/deep_learning_practices/data/faces/3273658251_b95f65c244.jpg
# [Rescale] new_size = 292 x 256
# img_name =  /home/nxtretail/workspace/practice/deep_learning_practices/data/faces/2647088981_60e9fe40cd.jpg
# [Rescale] new_size = 256 x 385
# img_name =  /home/nxtretail/workspace/practice/deep_learning_practices/data/faces/3855944735_e252959937.jpg
# [Rescale] new_size = 341 x 256
# [Rescale] new_size = 350 x 256
# img_name =  /home/nxtretail/workspace/practice/deep_learning_practices/data/faces/person_TjahjonoDGondhowiardjo.jpg
# [Rescale] new_size = 389 x 256
# [Rescale] new_size = 384 x 256
# img_name =  /home/nxtretail/workspace/practice/deep_learning_practices/data/faces/2956581526_cd803f2daa.jpg
# img_name =  /home/nxtretail/workspace/practice/deep_learning_practices/data/faces/3555944509_7b477069c6.jpg
# img_name =  /home/nxtretail/workspace/practice/deep_learning_practices/data/faces/2633371780_45b740b670.jpg
# [Rescale] new_size = 256 x 384
# [Rescale] new_size = 384 x 256
# [Rescale] new_size = 256 x 384
# img_name =  /home/nxtretail/workspace/practice/deep_learning_practices/data/faces/2795838930_0cc5aa5f41.jpg
# img_name =  /home/nxtretail/workspace/practice/deep_learning_practices/data/faces/3074791551_baee7fa0c1.jpg
# [Rescale] new_size = 256 x 384
# img_name =  /home/nxtretail/workspace/practice/deep_learning_practices/data/faces/303808204_1f744bc407.jpg
# img_name =  /home/nxtretail/workspace/practice/deep_learning_practices/data/faces/deeny.peggy.jpg
# [Rescale] new_size = 306 x 256
# [Rescale] new_size = 256 x 384
# [Rescale] new_size = 256 x 385
# img_name =  /home/nxtretail/workspace/practice/deep_learning_practices/data/faces/2173711035_dbd53b4f9f.jpg
# img_name =  /home/nxtretail/workspace/practice/deep_learning_practices/data/faces/1878519279_f905d4f34e.jpg
# img_name =  /home/nxtretail/workspace/practice/deep_learning_practices/data/faces/1383023626_8a49e4879a.jpg
# img_name =  /home/nxtretail/workspace/practice/deep_learning_practices/data/faces/1084239450_e76e00b7e7.jpg
# [Rescale] new_size = 256 x 384
# [Rescale] new_size = 256 x 385
# [Rescale] new_size = 384 x 256
# __len__ is called
# [Rescale] new_size = 382 x 256
# img_name =  /home/nxtretail/workspace/practice/deep_learning_practices/data/faces/2902323565_100017b63c.jpg
# img_name =  /home/nxtretail/workspace/practice/deep_learning_practices/data/faces/britney-bald.jpg
# [Rescale] new_size = 341 x 256
# [Rescale] new_size = 384 x 256
# img_name =  /home/nxtretail/workspace/practice/deep_learning_practices/data/faces/152601997_ec6429a43c.jpg
# img_name =  /home/nxtretail/workspace/practice/deep_learning_practices/data/faces/2382SJ8.jpg
# [Rescale] new_size = 256 x 383
# img_name =  /home/nxtretail/workspace/practice/deep_learning_practices/data/faces/362167809_d5a5dcbfdb.jpg
# [Rescale] new_size = 387 x 256
# img_name =  /home/nxtretail/workspace/practice/deep_learning_practices/data/faces/3856149136_d4595ffdd4.jpg
# img_name =  /home/nxtretail/workspace/practice/deep_learning_practices/data/faces/529447797_0f9d2fb756.jpg
# [Rescale] new_size = 384 x 256
# [Rescale] new_size = 256 x 342
# [Rescale] new_size = 256 x 286
# img_name =  /home/nxtretail/workspace/practice/deep_learning_practices/data/faces/2722779845_7fcb64a096.jpg
# img_name =  /home/nxtretail/workspace/practice/deep_learning_practices/data/faces/2210514040_6b03ff2629.jpg
# [Rescale] new_size = 256 x 384
# img_name =  /home/nxtretail/workspace/practice/deep_learning_practices/data/faces/2328398005_d328a70b4c.jpg
# img_name =  /home/nxtretail/workspace/practice/deep_learning_practices/data/faces/person-7.jpg
# [Rescale] new_size = 341 x 256
# [Rescale] new_size = 383 x 256
# img_name =  /home/nxtretail/workspace/practice/deep_learning_practices/data/faces/96063776_bdb3617b64.jpg
# 0 torch.Size([4, 3, 224, 224]) torch.Size([4, 68, 2])
# 1 torch.Size([4, 3, 224, 224]) torch.Size([4, 68, 2])
# 2 torch.Size([4, 3, 224, 224]) torch.Size([4, 68, 2])
# 3 torch.Size([4, 3, 224, 224]) torch.Size([4, 68, 2])
# [Rescale] new_size = 256 x 256
# img_name =  /home/nxtretail/workspace/practice/deep_learning_practices/data/faces/3534188114_2108895291.jpg
# img_name =  /home/nxtretail/workspace/practice/deep_learning_practices/data/faces/348272697_832ce65324.jpg
# [Rescale] new_size = 256 x 384
# img_name =  /home/nxtretail/workspace/practice/deep_learning_practices/data/faces/3872768751_e60d7fdbd5.jpg
# [Rescale] new_size = 256 x 341
# [Rescale] new_size = 256 x 384
# [Rescale] new_size = 341 x 256
# img_name =  /home/nxtretail/workspace/practice/deep_learning_practices/data/faces/97308305_4b737d0873.jpg
# img_name =  /home/nxtretail/workspace/practice/deep_learning_practices/data/faces/3534189272_8ef88ba368.jpg
# img_name =  /home/nxtretail/workspace/practice/deep_learning_practices/data/faces/57635685_d41c98f8ca.jpg
# img_name =  /home/nxtretail/workspace/practice/deep_learning_practices/data/faces/297448785_b2dda4b2c0.jpg
# [Rescale] new_size = 256 x 384
# [Rescale] new_size = 256 x 418
# [Rescale] new_size = 256 x 384
# [Rescale] new_size = 341 x 256
# img_name =  /home/nxtretail/workspace/practice/deep_learning_practices/data/faces/2046713398_91aaa6fe1c.jpg
# img_name =  /home/nxtretail/workspace/practice/deep_learning_practices/data/faces/137341995_e7c48e9a75.jpg
# img_name =  /home/nxtretail/workspace/practice/deep_learning_practices/data/faces/3152653555_68322314f3.jpg
# [Rescale] new_size = 362 x 256
# img_name =  /home/nxtretail/workspace/practice/deep_learning_practices/data/faces/252418361_440b75751b.jpg
# [Rescale] new_size = 384 x 256
# [Rescale] new_size = 256 x 318
# [Rescale] new_size = 256 x 384
# img_name =  /home/nxtretail/workspace/practice/deep_learning_practices/data/faces/3298715079_5af7c78fcb.jpg
# img_name =  /home/nxtretail/workspace/practice/deep_learning_practices/data/faces/110276240_bec305da91.jpg
# img_name =  /home/nxtretail/workspace/practice/deep_learning_practices/data/faces/0805personali01.jpg
# img_name =  /home/nxtretail/workspace/practice/deep_learning_practices/data/faces/10comm-decarlo.jpg
# [Rescale] new_size = 256 x 384
# [Rescale] new_size = 385 x 256
# [Rescale] new_size = 383 x 256
# [Rescale] new_size = 256 x 264
# img_name =  /home/nxtretail/workspace/practice/deep_learning_practices/data/faces/3718903026_c1bf5dfcf8.jpg
# img_name =  /home/nxtretail/workspace/practice/deep_learning_practices/data/faces/809285949_6889026b53.jpg
# img_name =  /home/nxtretail/workspace/practice/deep_learning_practices/data/faces/1549040388_b99e9fa295.jpg
# [Rescale] new_size = 256 x 320
# [Rescale] new_size = 383 x 256
# [Rescale] new_size = 256 x 340
# img_name =  /home/nxtretail/workspace/practice/deep_learning_practices/data/faces/3461016494_56cce9c984.jpg
# [Rescale] new_size = 256 x 383

# %% [markdown]
# Afterword: torchvision
# ----------------------
#
# In this tutorial, we have seen how to write and use datasets, transforms
# and dataloader. ``torchvision`` package provides some common datasets and
# transforms. You might not even have to write custom classes. One of the
# more generic datasets available in torchvision is ``ImageFolder``.
# It assumes that images are organized in the following way: ::
#
#     root/ants/xxx.png
#     root/ants/xxy.jpeg
#     root/ants/xxz.png
#     .
#     .
#     .
#     root/bees/123.jpg
#     root/bees/nsdf3.png
#     root/bees/asd932_.png
#
# where 'ants', 'bees' etc. are class labels. Similarly generic transforms
# which operate on ``PIL.Image`` like  ``RandomHorizontalFlip``, ``Scale``,
# are also available. You can use these to write a dataloader like this: ::

# %%
import torch
from torchvision import transforms, datasets

data_transform = transforms.Compose([
      transforms.RandomSizedCrop(224),
      transforms.RandomHorizontalFlip(),
      transforms.ToTensor(),
      transforms.Normalize(mean=[0.485, 0.456, 0.406],
                           std=[0.229, 0.224, 0.225])
  ])
hymenoptera_dataset = datasets.ImageFolder(root='hymenoptera_data/train',
                                         transform=data_transform)
dataset_loader = torch.utils.data.DataLoader(hymenoptera_dataset,
                                           batch_size=4, shuffle=True,
                                           num_workers=4)

# %% [markdown]
# For an example with training code, please see
# :doc:`transfer_learning_tutorial`.
